# %% [markdown]
# # 제목

# %% [markdown]
# ## 제목

# %%
import sys
for i in sys.path:
    print(i)
# Out:
# C:\Users\wneh2\AppData\Local\Programs\Python\Python39\python39.zip
# C:\Users\wneh2\AppData\Local\Programs\Python\Python39\DLLs
# C:\Users\wneh2\AppData\Local\Programs\Python\Python39\lib
# C:\Users\wneh2\AppData\Local\Programs\Python\Python39
# C:\Users\wneh2\Code\env3.9
#
# C:\Users\wneh2\Code\env3.9\lib\site-packages
# C:\Users\wneh2\Code\env3.9\lib\site-packages\win32
# C:\Users\wneh2\Code\env3.9\lib\site-packages\win32\lib
# C:\Users\wneh2\Code\env3.9\lib\site-packages\pythonwin

# %%
import site
print(site.getsitepackages())
# Out:
# ['C:\\Users\\wneh2\\Code\\env3.9', 'C:\\Users\\wneh2\\Code\\env3.9\\lib\\site-packages']

# %%
print(list(sys.modules.keys())[:20])
# Out:
# ['sys', 'builtins', '_frozen_importlib', '_imp', '_thread', '_warnings', '_weakref', '_io', 'marshal', 'nt', 'winreg', '_frozen_importlib_external', 'time', 'zipimport', '_codecs', 'codecs', 'encodings.aliases', 'encodings', 'encodings.utf_8', '_signal']

# %%
import sys
"math" in sys.modules
# Out:
# True

# %%
print(sys.executable)
# Out:
# C:\Users\wneh2\Code\env3.9\Scripts\python.exe

# %%
print(sys.version)
# Out:
# 3.9.13 (tags/v3.9.13:6de2ca5, May 17 2022, 16:36:42) [MSC v.1929 64 bit (AMD64)]
